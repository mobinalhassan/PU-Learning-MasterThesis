# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.optimizers import Adam
# import tensorflow_probability as tfp
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from uitils import *
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, BatchNormalization
from tensorflow.keras.regularizers import l2
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_curve, auc

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Data Loading

# %%
creditcard_path =get_full_path('../datasets/creditcard.csv')
# fraudulent=1 
# unlabeled=0
creditcard_df = pd.read_csv(creditcard_path)
x_train = creditcard_df.drop('Class', axis=1) 
y_train = creditcard_df['Class']

# Separate the positive and negative instances
positives = creditcard_df[creditcard_df['Class'] == 1]
negatives = creditcard_df[creditcard_df['Class'] == 0]

# Randomly sample 10,000 negative examples
neg_sample = negatives.sample(n=100000, random_state=42)

# Concatenate the positive examples with the sampled negative examples
sampled_df = pd.concat([positives, neg_sample])

# Shuffle the dataset to mix up the rows
sampled_df = sampled_df.sample(frac=1, random_state=42)

# Split the features and labels
x_train_sampled = sampled_df.drop('Class', axis=1)
y_train_sampled = sampled_df['Class']

# Split into training and test datasets
x_train, x_test, y_train, y_test = train_test_split(x_train_sampled, y_train_sampled, test_size=0.1, random_state=42)

# Print the training labels distribution to verify
print("Training labels distribution:", np.bincount(y_train))

# %%
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
# x_train, y_train = extract_samples(x_train, y_train, 300)
# x_test, y_test = extract_samples(x_test, y_test, 100)
# print("Reduced training set shape:", x_train.shape)
# print("Reduced testing set shape:", x_test.shape)
# x_train = x_train / 255.0
# x_test = x_test / 255.0
# y_train = y_train % 2  # Convert labels to 0 (even) and 1 (odd) 
# y_test = y_test % 2
# s=y_train

# # Initialize 's' to zeros, meaning initially all are unlabeled
# # s = np.zeros_like(y_train)

# # # Select a random 300 samples where y_train == 1 to be labeled
# # positive_indices = np.where(y_train == 1)[0]
# # chosen_indices = np.random.choice(positive_indices, size=300, replace=False)

# # # Mark these as labeled in 's'
# # s[chosen_indices] = 1

# # # Mark the rest of the positive_indices except the chosen 300 as potential targets for unlabeled marking
# # rest_of_positives = np.setdiff1d(positive_indices, chosen_indices)

# # # From the rest, select 30% and mark their labels as 0 in y_train
# # number_to_mark_unlabeled = int(len(rest_of_positives) * 0.03)
# # unlabeled_indices = np.random.choice(rest_of_positives, size=number_to_mark_unlabeled, replace=False)
# # y_train[unlabeled_indices] = 0

# # # Remove the rest of the positive rows that are not in the chosen 300 and not marked as unlabeled
# # indices_to_drop = np.setdiff1d(rest_of_positives, np.concatenate([chosen_indices, unlabeled_indices]))
# # x_train = np.delete(x_train, indices_to_drop, axis=0)
# # y_train = np.delete(y_train, indices_to_drop)
# # s = np.delete(s, indices_to_drop)

# print("Training labels distribution:", np.bincount(y_train))
# print("Training original labels distribution:", np.bincount(s))
# Out:
# Reduced training set shape: (3000, 28, 28)
# Reduced testing set shape: (1000, 28, 28)
# Training labels distribution: [1500 1500]
# Training original labels distribution: [1500 1500]

# %%
# def create_pu_datasets(x, y, n_labeled, pos_fraction):
#     # Select a random 300 rows where y_train == 1
#     positive_indices = np.where(y_train == 1)[0]
#     chosen_indices = np.random.choice(positive_indices, size=n_labeled, replace=False)

#     # Mark the rest of the positive_indices except the chosen 300 as potential targets for unlabeled marking
#     rest_of_positives = np.setdiff1d(positive_indices, chosen_indices)

#     # From the rest, select 30% and mark their labels as 0
#     number_to_mark_unlabeled = int(len(rest_of_positives) * pos_fraction)
#     unlabeled_indices = np.random.choice(rest_of_positives, size=number_to_mark_unlabeled, replace=False)
#     y_train[unlabeled_indices] = 0

#     # Remove the rest of the rows where y=1 that are not in the chosen 300
#     indices_to_drop = np.setdiff1d(rest_of_positives, unlabeled_indices)
#     x_train = np.delete(x_train, indices_to_drop, axis=0)
#     y_train = np.delete(y_train, indices_to_drop)

#     return x_train, y_train

# # Create datasets as per specifications from the paper
# # configs = [(300, 0.3), (500, 0.5), (1000, 0.7)]
# configs = [(300, 0.3)]
# datasets = [create_pu_datasets(x_train, y_train, n, frac) for n, frac in configs]

# for i, (train_x_pu, train_y_pu) in enumerate(datasets):
#     print(f"Configuration {i+1} label distribution: {np.bincount(train_y_pu.astype(int))}")

# %% [markdown]
# # Pre-training

# %%
weight_decay = 2.0
model_1 = Sequential([
    Conv2D(96, (3, 3), padding='same', input_shape=(28, 28, 1), kernel_regularizer=l2(weight_decay)),
    # BatchNormalization(),
    Activation('relu'),
    Conv2D(192, (3, 3), padding='same', kernel_regularizer=l2(weight_decay)),
    # BatchNormalization(),
    Activation('relu'),
    Conv2D(10, (1, 1), padding='same', kernel_regularizer=l2(weight_decay)),
    # BatchNormalization(),
    Activation('relu'),
    Flatten(),
    Dense(100, kernel_regularizer=l2(weight_decay)),
    Activation('relu'),
    Dense(100, kernel_regularizer=l2(weight_decay)),
    Activation('relu'),
    Dense(1, kernel_regularizer=l2(weight_decay)),
    Activation('sigmoid')
])


model_1.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])
history_1 = model_1.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2)
# model_1.save_weights('clf_model_.weights.h5')
# model_1.load_weights('clf_model_.weights.h5')
# Out:
# Epoch 1/5
# 19/19 [==============================] - 14s 347ms/step - loss: 892.9271 - accuracy: 0.4504 - val_loss: 886.5659 - val_accuracy: 0.4867
# Epoch 2/5
# 19/19 [==============================] - 3s 151ms/step - loss: 881.0376 - accuracy: 0.4558 - val_loss: 874.7719 - val_accuracy: 0.4883
# Epoch 3/5
# 19/19 [==============================] - 3s 149ms/step - loss: 869.3322 - accuracy: 0.4608 - val_loss: 863.1688 - val_accuracy: 0.4833
# Epoch 4/5
# 19/19 [==============================] - 3s 154ms/step - loss: 857.8189 - accuracy: 0.4667 - val_loss: 851.7578 - val_accuracy: 0.4817
# Epoch 5/5
# 19/19 [==============================] - 3s 154ms/step - loss: 846.4962 - accuracy: 0.4737 - val_loss: 840.5353 - val_accuracy: 0.4850

# %% [markdown]
# ### Probablistic outcome of classifer to pre-train policy network

# %%
probabilities = model_1.predict(x_train)
threshold = min(probabilities[y_train == 1])

# Convert probabilities to binary labels based on the threshold
predicted_labels = (probabilities >= threshold).astype(int)
clf_predicted_labels = predicted_labels.flatten().astype(int)

print("Classifer predicted labels distribution:", np.bincount(clf_predicted_labels))
# Out:
# 94/94 [==============================] - 3s 21ms/step
# Classifer predicted labels distribution: [   0 3000]

# %%
# Policy-Network Model

class PolicyGradientNetwork:
    def __init__(self):
        self.model = self._create_model()
    
    def _create_model(self):
        weight_decay = 0.5
        model = Sequential([
            Conv2D(96, (3, 3), padding='same', input_shape=(28, 28, 1), kernel_regularizer=l2(weight_decay)),
            Activation('relu'),
            Conv2D(10, (3, 3), padding='same', kernel_regularizer=l2(weight_decay)),
            Activation('relu'),
            Flatten(),
            Dense(100, kernel_regularizer=l2(weight_decay)),
            Activation('relu'),
            Dense(100, kernel_regularizer=l2(weight_decay)),  # Additional Dense layer
            Activation('relu'),
            Dense(1, kernel_regularizer=l2(weight_decay)),  # Softmax output for binary classification
            Activation('sigmoid') # Hard labeling
        ])
        return model
    
    def get_model(self):
        return self.model
    

policy_network = PolicyGradientNetwork()
pn_model = policy_network.get_model()

pn_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

history_2 = pn_model.fit(x_train, clf_predicted_labels, epochs=5, batch_size=128, validation_split=0.2)
# pn_model.save_weights('pn_model_.weights.h5')
# pn_model.load_weights('pn_model_.weights.h5')
# Out:
# Epoch 1/5
# 19/19 [==============================] - 3s 126ms/step - loss: 159.0348 - accuracy: 0.0796 - val_loss: 157.8284 - val_accuracy: 0.0583
# Epoch 2/5
# 19/19 [==============================] - 2s 83ms/step - loss: 156.7805 - accuracy: 0.1446 - val_loss: 155.5939 - val_accuracy: 0.1217
# Epoch 3/5
# 19/19 [==============================] - 1s 79ms/step - loss: 154.5645 - accuracy: 0.2179 - val_loss: 153.3992 - val_accuracy: 0.2067
# Epoch 4/5
# 19/19 [==============================] - 2s 88ms/step - loss: 152.3886 - accuracy: 0.3233 - val_loss: 151.2444 - val_accuracy: 0.3150
# Epoch 5/5
# 19/19 [==============================] - 2s 87ms/step - loss: 150.2522 - accuracy: 0.4538 - val_loss: 149.1288 - val_accuracy: 0.4617

# %%
probabilities = pn_model.predict(x_train)
threshold = min(probabilities[y_train == 1])

# Convert probabilities to binary labels based on the threshold
predicted_labels = (probabilities >= threshold).astype(int)
np_predicted_labels = predicted_labels.flatten().astype(int)

print("Classifer predicted labels distribution:", np.bincount(np_predicted_labels))
# Out:
# 94/94 [==============================] - 1s 11ms/step
# Classifer predicted labels distribution: [   4 2996]

# %% [markdown]
# ## Interactive learning

# %%
import tensorflow as tf
import numpy as np

class Agent:
    def __init__(self, model, target_model, alpha=0.00001, gamma=0.99):
        self.gamma = gamma  # Discount factor
        self.lr = alpha  # Learning rate
        self.model = model  # Policy model
        self.target_model = target_model # target policy model
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []

    def choose_action(self, states, s, threshold=0.5):
        # Convert states to float32 tensor within the function
        states = tf.convert_to_tensor(states, dtype=tf.float32)
        probabilities = self.target_model(states)  # Make sure target model expects float32 input
        # action_sampler = tfp.distributions.Bernoulli(probs=probabilities, dtype=tf.float32)
        # actions = action_sampler.sample()
        # print(f"probabilities ={probabilities}")
        # actions = tf.cast(tf.random.uniform(tf.shape(probabilities)) < probabilities, tf.int32)

        inferred_labels = tf.cast(probabilities > threshold, tf.int32)       
        s = tf.reshape(s, tf.shape(inferred_labels))  # Ensuring s is the same shape as inferred_labels
        actions = tf.where(s == 1, 1, inferred_labels)
        actions = tf.squeeze(actions)  # This should correctly squeeze actions to shape (128,)
        return actions.numpy(), probabilities.numpy()


    def store_transition(self, states, actions, rewards):
        self.state_memory.extend(states)
        self.action_memory.extend(actions)
        self.reward_memory.extend(rewards)

    def learn(self):
        actions = np.array(self.action_memory)
        rewards = np.array(self.reward_memory)
        states = np.array(self.state_memory)

        # Calculate discounted rewards
        G = np.zeros_like(rewards)
        for t in range(len(rewards)):
            G_sum = 0
            discount = 1
            for k in range(t, len(rewards)):
                G_sum += rewards[k] * discount
                discount *= self.gamma
            G[t] = G_sum

        # Updating policy
        with tf.GradientTape() as tape:
            loss = 0
            for idx, (g, state) in enumerate(zip(G, states)):
                state = tf.convert_to_tensor([state], dtype=tf.float32)
                probs = self.model(state, training=True)
                # action_probs = tfp.distributions.Bernoulli(probs=probs)
                # log_prob = action_probs.log_prob(actions[idx])
                # loss += -g * tf.reduce_sum(log_prob)
                action_probs = tf.where(actions[idx] == 1, probs, 1 - probs)
                log_prob = tf.math.log(action_probs)
                loss += -g * tf.reduce_sum(log_prob)

        gradients = tape.gradient(loss, self.model.trainable_variables)
        self.model.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

        # Clear memory
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []

# %%
# Clone policy model for stable target policy
target_policy_model = tf.keras.models.clone_model(pn_model)
target_policy_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

history = {
    'epoch_loss': [],
    'epoch_accuracy': [],
    'batch_loss': [],
    'batch_accuracy': [],
    'predictions': [],
    'rewards': [],
    'thresholds': [],
    'ROC_AUC': [],
    'accuracy':[],
    'PR_AUC':[]
}
agent = Agent(pn_model,target_model=target_policy_model, alpha=0.00001, gamma=0.99)
# Example parameters
n_epochs = 300
n_epochs = 10
batch_size = 128 # You can adjust the batch size as needed

def shuffle_data(x_train, y_train, s):
    indices = np.arange(len(x_train))
    np.random.shuffle(indices)
    return x_train[indices], y_train[indices], s[indices]

def create_mini_batches(x_train, y_train, s, batch_size):
    for start_idx in range(0, len(x_train) - batch_size + 1, batch_size):
        excerpt = slice(start_idx, start_idx + batch_size)
        yield x_train[excerpt], y_train[excerpt], s[excerpt]

def calculate_threshold(clf_probabilities, y_batch):
    # Identify indices of positive examples
    positive_indices = (y_batch == 1)
    
    # Calculate threshmin from positive examples
    if np.any(positive_indices):
        threshmin = np.min(clf_probabilities[positive_indices])
    else:
        threshmin = 0  # Default value if no positive examples are present

    # Identify U0 - samples with predictions >= threshmin
    U0_indices = (clf_probabilities >= threshmin)
    
    # Calculate the final threshold using Equation 5
    if np.any(U0_indices):
        threshold = np.mean(clf_probabilities[U0_indices])
    else:
        threshold = threshmin  # Use threshmin if no samples meet the U0 criteria

    return threshold

def calculate_rewards(clf_probabilities, y_batch, threshold):
    # Reward calculation needs to consider whether predictions meet a certain threshold
    # Positive examples above threshold or negative examples below threshold get positive rewards
    rewards = []
    for prob, actual in zip(clf_probabilities.flatten(), y_batch):
        if actual == 1 or (actual == 0 and prob >= threshold):
            reward = prob  # Reward is the probability itself if conditions are met
        else:
            reward = prob -1  # Otherwise, reward is the complement of the probability
        rewards.append(reward)
    return rewards

# %%
def train_model(x_train, y_train, s, epochs=300, batch_size=128, min_delta=0.0001, patience=10):
    x_train = x_train.astype('float32')
    y_train = y_train.astype('float32')
    s = s.astype('float32')

    dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train, s))
    dataset = dataset.shuffle(buffer_size=len(x_train)).batch(batch_size)

    # early_stopping = EarlyStopping(monitor='val_accuracy', patience=patience, min_delta=min_delta, mode='max', restore_best_weights=True, verbose=1)

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        epoch_loss = 0
        epoch_accuracy = 0
        batch_count = 0
        # first_iteration = True
        # threshold_pass = 0.5
        threshold = 0.5
        for x_batch, y_batch, s_batch in dataset:
            # Get actions and probabilities for the entire batch
            actions, probabilities = agent.choose_action(x_batch, s_batch, threshold=threshold)

            # Fit the model on the current batch and update history
            batch_history = model_1.fit(x_batch, actions, epochs=1, batch_size=len(x_batch), validation_split=0.2, verbose=0)
            history['batch_loss'].append(batch_history.history['loss'][0])
            history['batch_accuracy'].append(batch_history.history['accuracy'][0])
            epoch_loss += batch_history.history['loss'][0]
            epoch_accuracy += batch_history.history['accuracy'][0]
            batch_count += 1

            clf_probabilities = model_1.predict(x_batch)
            threshold = calculate_threshold(clf_probabilities, y_batch)
            rewards = calculate_rewards(clf_probabilities, y_batch, threshold)
            agent.store_transition(x_batch.numpy(), actions, rewards)
            agent.learn()
            # break
        first_iteration = True
        epoch_loss /= batch_count
        epoch_accuracy /= batch_count
        history['epoch_loss'].append(epoch_loss)
        history['epoch_accuracy'].append(epoch_accuracy)
        print(f"Epoch {epoch+1}: Loss = {epoch_loss}, Accuracy = {epoch_accuracy}")

        # early stopping condition
        # if epoch > 0 and (history['epoch_accuracy'][-1] - history['epoch_accuracy'][-2]) < min_delta:
        #     print("Early stopping triggered.")
        #     break

        probabilities = model_1.predict(x_test)  # Ensure this is the probability of the positive class
        roc_auc = roc_auc_score(y_true=y_test, y_score=probabilities)
        history['ROC_AUC'].append(roc_auc)
        # Predict probabilities for the positive class
        # probabilities = model_1.predict(x_test)
        precision, recall, _ = precision_recall_curve(y_true=y_test, probas_pred=probabilities)
        pr_auc = auc(recall, precision)
        history['PR_AUC'].append(pr_auc)
        # predictions = (model_1.predict(x_test) > 0.5).astype(int)
        predictions = (probabilities > 0.5).astype(int)
        accuracy = accuracy_score(y_true=y_test, y_pred=predictions)
        history['accuracy'].append(pr_auc)
        print("ROC AUC Score:", roc_auc)
        print("Accuracy Score:", accuracy)
        print("Precision-Recall AUC:", pr_auc)
        

        if epoch % 3 == 0:
            print("Updating target policy...")
            agent.target_model.set_weights(agent.model.get_weights())


train_model(x_train=x_train, y_train=y_train, s=s)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 13ms/step
# Epoch 1: Loss = 833.848772684733, Accuracy = 0.1146019041383018
# 32/32 [==============================] - 1s 23ms/step
# ROC AUC Score: 0.48184399999999994
# Accuracy Score: 0.459
# Precision-Recall AUC: 0.4605949791548218
# Updating target policy...
# Epoch 2/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 2: Loss = 820.0700556437174, Accuracy = 0.3753713679810365
# 32/32 [==============================] - 1s 16ms/step
# ROC AUC Score: 0.464092
# Accuracy Score: 0.476
# Precision-Recall AUC: 0.4501122822280171
# Epoch 3/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 3: Loss = 806.5729395548502, Accuracy = 0.7666369577248892
# 32/32 [==============================] - 1s 21ms/step
# ROC AUC Score: 0.448444
# Accuracy Score: 0.517
# Precision-Recall AUC: 0.4419839059344647
# Epoch 4/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 4: Loss = 793.3500061035156, Accuracy = 0.9685457398494085
# 32/32 [==============================] - 1s 17ms/step
# ROC AUC Score: 0.4366479999999999
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.43624592670548973
# Updating target policy...
# Epoch 5/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 5: Loss = 780.3940938313802, Accuracy = 0.9987745061516762
# 32/32 [==============================] - 1s 19ms/step
# ROC AUC Score: 0.428438
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.43259510810431845
# Epoch 6/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# Epoch 6: Loss = 767.6980463663737, Accuracy = 1.0
# 32/32 [==============================] - 1s 16ms/step
# ROC AUC Score: 0.42110400000000003
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.429366746366133
# Epoch 7/300
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 4s 14ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 4s 17ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 5s 12ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 28ms/step
# Epoch 7: Loss = 755.2550837198893, Accuracy = 1.0
# 32/32 [==============================] - 5s 154ms/step
# ROC AUC Score: 0.4150459999999999
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4251454819267544
# Updating target policy...
# Epoch 8/300
# 4/4 [==============================] - 4s 16ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 5s 2s/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 8: Loss = 743.0589955647787, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.409674
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4225878359248706
# Epoch 9/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
# Epoch 9: Loss = 731.1035766601562, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.403984
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.42008248171965024
# Epoch 10/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 5s 14ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 10: Loss = 719.3830718994141, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.39816799999999997
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4175023002093148
# Updating target policy...
# Epoch 11/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 11: Loss = 707.8921763102213, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.395526
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4164822035537445
# Epoch 12/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 12: Loss = 696.6251703898112, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.39638400000000007
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4173664233912344
# Epoch 13/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 13: Loss = 685.5772399902344, Accuracy = 1.0
# 32/32 [==============================] - 1s 19ms/step
# ROC AUC Score: 0.401344
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.41982041900788347
# Updating target policy...
# Epoch 14/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 14: Loss = 674.7432505289713, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.40854799999999997
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4238019455176285
# Epoch 15/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 15: Loss = 664.1185582478842, Accuracy = 1.0
# 32/32 [==============================] - 1s 19ms/step
# ROC AUC Score: 0.41598999999999997
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.42808224321114763
# Epoch 16/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 16: Loss = 653.6983311971029, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.423538
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4324456258077901
# Updating target policy...
# Epoch 17/300
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 17: Loss = 643.4781545003256, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.430578
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.43587449182209864
# Epoch 18/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 18: Loss = 633.4536895751953, Accuracy = 1.0
# 32/32 [==============================] - 1s 21ms/step
# ROC AUC Score: 0.43897400000000003
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.43946277987901156
# Epoch 19/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 19: Loss = 623.6206792195638, Accuracy = 1.0
# 32/32 [==============================] - 1s 18ms/step
# ROC AUC Score: 0.447774
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.44276754680078456
# Updating target policy...
# Epoch 20/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 20: Loss = 613.9748357137045, Accuracy = 1.0
# 32/32 [==============================] - 1s 21ms/step
# ROC AUC Score: 0.45948999999999995
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.44787570388529546
# Epoch 21/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 21: Loss = 604.5123291015625, Accuracy = 1.0
# 32/32 [==============================] - 1s 19ms/step
# ROC AUC Score: 0.47301
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4537543527676767
# Epoch 22/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 22: Loss = 595.2293345133463, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.48423199999999994
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4588135622772028
# Updating target policy...
# Epoch 23/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 23: Loss = 586.1219151814779, Accuracy = 1.0
# 32/32 [==============================] - 1s 19ms/step
# ROC AUC Score: 0.49430599999999997
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4639750460031362
# Epoch 24/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 24: Loss = 577.186393737793, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.506844
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.47122700746099927
# Epoch 25/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 25: Loss = 568.419075012207, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.518196
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.47808336028278553
# Updating target policy...
# Epoch 26/300
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 26: Loss = 559.8168334960938, Accuracy = 1.0
# 32/32 [==============================] - 1s 14ms/step
# ROC AUC Score: 0.52884
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.48546650004904435
# Epoch 27/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 27: Loss = 551.3762334187826, Accuracy = 1.0
# 32/32 [==============================] - 1s 21ms/step
# ROC AUC Score: 0.539064
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4927228937141821
# Epoch 28/300
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 28: Loss = 543.0939178466797, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.549852
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.5005233780591247
# Updating target policy...
# Epoch 29/300
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 10ms/step
# Epoch 29: Loss = 534.9667841593424, Accuracy = 1.0
# 32/32 [==============================] - 4s 118ms/step
# ROC AUC Score: 0.556904
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.5052290114980267
# Epoch 30/300
# 4/4 [==============================] - 3s 30ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 3s 15ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 3s 29ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 4s 16ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 3s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 17ms/step
# Epoch 30: Loss = 526.9917984008789, Accuracy = 1.0
# 32/32 [==============================] - 1s 16ms/step
# ROC AUC Score: 0.564292
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.5102921719410227
# Epoch 31/300
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 3s 951ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 31: Loss = 519.1658477783203, Accuracy = 1.0
# 32/32 [==============================] - 1s 21ms/step
# ROC AUC Score: 0.56974
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.5141431854061018
# Updating target policy...
# Epoch 32/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 32: Loss = 511.48600641886395, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.574342
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.5174640365985403
# Epoch 33/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 33ms/step
# ...
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 290: Loss = 60.05954917271932, Accuracy = 1.0
# 32/32 [==============================] - 1s 14ms/step
# ROC AUC Score: 0.335644
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.40109487335786914
# Epoch 291/300
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 291: Loss = 59.705933570861816, Accuracy = 1.0
# 32/32 [==============================] - 0s 10ms/step
# ROC AUC Score: 0.335674
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4011076890454563
# Epoch 292/300
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 32ms/step
# Epoch 292: Loss = 59.35388962427775, Accuracy = 1.0
# 32/32 [==============================] - 0s 13ms/step
# ROC AUC Score: 0.33564399999999994
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4010874225490612
# Updating target policy...
# Epoch 293/300
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 30ms/step
# Epoch 293: Loss = 59.0034384727478, Accuracy = 1.0
# 32/32 [==============================] - 0s 13ms/step
# ROC AUC Score: 0.33563
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.40108819320716044
# Epoch 294/300
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 33ms/step
# Epoch 294: Loss = 58.65456501642863, Accuracy = 1.0
# 32/32 [==============================] - 1s 20ms/step
# ROC AUC Score: 0.33562
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4010755873093899
# Epoch 295/300
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 295: Loss = 58.307267824808754, Accuracy = 1.0
# 32/32 [==============================] - 1s 14ms/step
# ROC AUC Score: 0.33566599999999996
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4011090060146977
# Updating target policy...
# Epoch 296/300
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 296: Loss = 57.961491425832115, Accuracy = 1.0
# 32/32 [==============================] - 0s 11ms/step
# ROC AUC Score: 0.335654
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.40109813948314776
# Epoch 297/300
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 297: Loss = 57.617247104644775, Accuracy = 1.0
# 32/32 [==============================] - 1s 14ms/step
# ROC AUC Score: 0.33564
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4010949296773956
# Epoch 298/300
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 10ms/step
# Epoch 298: Loss = 57.27455552419027, Accuracy = 1.0
# 32/32 [==============================] - 0s 10ms/step
# ROC AUC Score: 0.335642
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.40110391327824324
# Updating target policy...
# Epoch 299/300
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 30ms/step
# Epoch 299: Loss = 56.933385054270424, Accuracy = 1.0
# 32/32 [==============================] - 0s 12ms/step
# ROC AUC Score: 0.3356
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4010857543219145
# Epoch 300/300
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# Epoch 300: Loss = 56.59371169408163, Accuracy = 1.0
# 32/32 [==============================] - 0s 10ms/step
# ROC AUC Score: 0.335634
# Accuracy Score: 0.5
# Precision-Recall AUC: 0.4010818453592365

# %%
import pickle
with open('history_2.pkl', 'wb') as file:
    # Use pickle to dump the dictionary into the file
    pickle.dump(history, file)

with open('history_2.pkl', 'rb') as file:
    # Load the dictionary back from the pickle file
    loaded_history = pickle.load(file)

# Verify the content
print(loaded_history)
# Out:
# {'epoch_loss': [833.848772684733, 820.0700556437174, 806.5729395548502, 793.3500061035156, 780.3940938313802, 767.6980463663737, 755.2550837198893, 743.0589955647787, 731.1035766601562, 719.3830718994141, 707.8921763102213, 696.6251703898112, 685.5772399902344, 674.7432505289713, 664.1185582478842, 653.6983311971029, 643.4781545003256, 633.4536895751953, 623.6206792195638, 613.9748357137045, 604.5123291015625, 595.2293345133463, 586.1219151814779, 577.186393737793, 568.419075012207, 559.8168334960938, 551.3762334187826, 543.0939178466797, 534.9667841593424, 526.9917984008789, 519.1658477783203, 511.48600641886395, 503.9493357340495, 496.55301030476886, 489.29428990681964, 482.1703910827637, 475.17880121866864, 468.3169809977214, 461.58227284749347, 454.9723637898763, 448.48468653361004, 442.1169713338216, 435.86695607503253, 429.7322807312012, 423.7107213338216, 417.80023193359375, 411.9985605875651, 406.30366134643555, 400.7135416666667, 395.2261670430501, 389.8395309448242, 384.55177307128906, 379.3610102335612, 374.2653528849284, 369.26307423909503, 364.3523406982422, 359.5314572652181, 354.79866282145184, 350.15232213338214, 345.5907897949219, 341.11246490478516, 336.7156677246094, 332.3989741007487, 328.1608174641927, 323.99971771240234, 319.91419347127277, 315.9028383890788, 311.9641749064128, 308.0968526204427, 304.29955164591473, 300.5708605448405, 296.9094886779785, 293.3141288757324, 289.78358205159503, 286.3165804545085, 282.9118347167969, 279.56822840372723, 276.2845268249512, 273.0596008300781, 269.8922602335612, 266.7814776102702, 263.72611745198566, 260.72502517700195, 257.7771352132161, 254.88151359558105, 252.03716532389322, 249.24300066630045, 246.49806022644043, 243.8014087677002, 241.1520455678304, 238.54901758829752, 235.99146842956543, 233.47850227355957, 231.00916290283203, 228.58265368143717, 226.19804318745932, 223.8545265197754, 221.55130894978842, 219.28757349650064, 217.06243069966635, 214.87520599365234, 212.72509829203287, 210.61136309305826, 208.53318659464517, 206.4900105794271, 204.48091316223145, 202.50535774230957, 200.56253306070963, 198.6518643697103, 196.77263577779135, 194.92422358194986, 193.10589981079102, 191.31715965270996, 189.5572878519694, 187.8257910410563, 186.12196159362793, 184.44528325398764, 182.7951488494873, 181.17104276021323, 179.5724080403646, 177.9986457824707, 176.44933891296387, 174.92388788859049, 173.42177772521973, 171.9425729115804, 170.4857381184896, 169.05080350240073, 167.6373208363851, 166.24481582641602, 164.87285931905112, 163.52100944519043, 162.1887995402018, 160.87582461039224, 159.58172480265299, 158.30602582295737, 157.04840469360352, 155.80839411417642, 154.58567110697427, 153.37982559204102, 152.1905714670817, 151.01748530069986, 149.86026573181152, 148.71854146321616, 147.59198125203451, 146.48031361897787, 145.38316663106283, 144.30024655659994, 143.2313143412272, 142.17599550882974, 141.13403256734213, 140.1050287882487, 139.08869806925455, 138.08504740397134, 137.09370803833008, 136.11441612243652, 135.14692242940268, 134.19096692403158, 133.24628829956055, 132.31267674763998, 131.38998095194498, 130.4779020945231, 129.57627296447754, 128.68486150105795, 127.80345884958903, 126.9318806330363, 126.06995169321696, 125.2174555460612, 124.37424182891846, 123.54010899861653, 122.71488952636719, 121.89842796325684, 121.0905335744222, 120.29107983907063, 119.49988269805908, 118.71661917368571, 117.94131596883138, 117.17392603556316, 116.41414324442546, 115.66190687815349, 114.91712506612141, 114.17963759104411, 113.44935353597005, 112.72612984975179, 112.00982475280762, 111.30034192403157, 110.59753131866455, 109.90130106608073, 109.21152528127034, 108.52811272939046, 107.85095405578613, 107.17993831634521, 106.5149793624878, 105.85596783955891, 105.20281378428142, 104.55541292826335, 103.91368230183919, 103.27754020690918, 102.64687379201253, 102.02162456512451, 101.40169111887614, 100.78699652353923, 100.17745463053386, 99.57298914591472, 98.9735237757 ...

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_curve, auc
# Predict probabilities for the positive class
probabilities = model_1.predict(x_test)  # Ensure this is the probability of the positive class
roc_auc = roc_auc_score(y_true=y_test, y_score=probabilities)
print("ROC AUC Score:", roc_auc)

# Predict class labels based on a threshold, typically 0.5 for binary classifiers
predictions = (model_1.predict(x_test) > 0.5).astype(int)
accuracy = accuracy_score(y_true=y_test, y_pred=predictions)
print("Accuracy Score:", accuracy)

# Predict probabilities for the positive class
probabilities = model_1.predict(x_test)
precision, recall, _ = precision_recall_curve(y_true=y_test, probas_pred=probabilities)
pr_auc = auc(recall, precision)
print("Precision-Recall AUC:", pr_auc)
# Out:
# 32/32 [==============================] - 1s 14ms/step
# ROC AUC Score: 0.335634
# 32/32 [==============================] - 1s 14ms/step
# Accuracy Score: 0.5
# 32/32 [==============================] - 1s 14ms/step
# Precision-Recall AUC: 0.4010818453592365

# %%
target_policy_model.save_weights('target_policy_model_2.weights.h5')
model_1.save_weights('clf_model_after_IL_2.weights.h5')

# %% [markdown]
# history = {
#     'epoch_loss': [],
#     'epoch_accuracy': [],
#     'batch_loss': [],
#     'batch_accuracy': [],
#     'predictions': [],
#     'rewards': [],
#     'thresholds': [],
#     'ROC_AUC': [],
#     'accuracy':[],
#     'PR_AUC':[]
# }

# %%
import matplotlib.pyplot as plt

# Plotting epoch losses and accuracies
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history['epoch_loss'], label='Loss')
plt.title('Epoch Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history['epoch_accuracy'], label='Accuracy')
plt.title('Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# You can add more plots for batch-level data, rewards, thresholds, etc.

# %% [markdown]
# # Visual

# %%
# Plotting epoch losses and accuracies
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history['batch_loss'], label='Loss')
plt.title('Batch Loss')
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history['batch_accuracy'], label='Accuracy')
plt.title('Batch Accuracy')
plt.xlabel('Batch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Plotting epoch losses and accuracies 'ROC_AUC': [],
    # 'accuracy':[],
    # 'PR_AUC':[]
plt.figure(figsize=(14, 5))

plt.subplot(1, 3, 1)
plt.plot(history['ROC_AUC'], label='Loss')
plt.title('ROC AUC')
plt.xlabel('Epoch')
plt.ylabel('ROC')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history['accuracy'], label='Accuracy')
plt.title('Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history['PR_AUC'], label='Accuracy')
plt.title('PR AUC')
plt.xlabel('Epoch')
plt.ylabel('PR@Epoch')
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_images(images, labels, predictions=None):
    """Plot images with their labels. Show predictions if provided."""
    n = images.shape[0]
    sqrt_val = int(np.ceil(np.sqrt(n)))
    fig, axes = plt.subplots(sqrt_val, sqrt_val, figsize=(10, 10))
    
    for i, ax in enumerate(axes.flat):
        if i >= n:
            break
        ax.imshow(images[i], cmap='binary')
        
        if predictions is not None:
            ax.set_title(f"True: {labels[i]}\nPred: {predictions[i]}")
        else:
            ax.set_title(f"Label: {labels[i]}")
        
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()

# Predictions from the second classifier
predictions = target_policy_model.predict(x_test)
predicted_classes = (predictions > 0.5).astype(int).flatten()  # Assuming binary classification

# Selecting a few images to display
indices = np.random.choice(range(len(x_test)), 25, replace=False)  # Randomly select 25 images
selected_images = x_test[indices]
selected_labels = y_test[indices]
selected_predictions = predicted_classes[indices]

# Plotting
plot_images(selected_images, selected_labels, selected_predictions)
# Out:
# 32/32 [==============================] - 1s 14ms/step

# %%
def plot_history(history):
    """Plot training and validation loss and accuracy."""
    fig, axs = plt.subplots(2, 1, figsize=(10, 10))
    axs[0].plot(history.history['loss'], label='train')
    axs[0].plot(history.history['val_loss'], label='validation')
    axs[0].set_title('Loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()

    axs[1].plot(history.history['accuracy'], label='train')
    axs[1].plot(history.history['val_accuracy'], label='validation')
    axs[1].set_title('Accuracy')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()

    plt.show()

# Assuming you have stored the history of training your models as `history_1` and `history_2`
plot_history(history_1)  # For the first classifier
plot_history(history_2)  # For the second classifier
