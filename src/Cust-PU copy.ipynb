# %%
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp
import tensorflow as tf

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # Data Loading

# %%
# Load and preprocess MNIST data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
y_train = y_train % 2  # Convert labels to 0 (even) and 1 (odd) 
y_train_original = y_train.copy()  # {original labels} 
y_test = y_test % 2
y_test_original = y_test.copy()

# Mark a subset of positive instances as unlabeled
positive_indices = np.where(y_train == 1)[0]
unlabeled_indices = np.random.choice(positive_indices, size=int(len(positive_indices) * 0.8), replace=False)
y_train[unlabeled_indices] = 0  # Marking unlabeled now y_train is PU dataset


X = x_train  # Your feature matrix

# Preparing 's', the binary indicator vector
# Start by marking all instances as 'unlabeled' (0)
s = np.zeros_like(y_train)
# Then, mark the originally positive instances as 'labeled' (1), excluding those you've marked as unlabeled
s[positive_indices] = 1
s[unlabeled_indices] = 0 # where s=0 y can be either y=1 or y=0

print("Training labels distribution:", np.bincount(y_train))
print("Training original labels distribution:", np.bincount(y_train_original))
# Out:
# Training labels distribution: [53898  6102]
# Training original labels distribution: [29492 30508]

# %% [markdown]
# n_epochs=300
# for epoch = 1 to n_epochs do
#     Suffel to create mini-batch
#     for each mini-bach do:
#         pass (I'll call function here by my self)
#     end for
#     if (check to call update function) I want to run this every 3 epoch:
#         update_policy()
#     end if
# end for

# %% [markdown]
# # Pre-training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, BatchNormalization

model_1 = Sequential([
    Conv2D(96, (3, 3), padding='same', input_shape=(28, 28, 1)),  # First convolutional layer with 96 filters
    Activation('relu'),
    Conv2D(192, (3, 3), padding='same'),  # Second convolutional layer with 192 filters
    Activation('relu'),
    Conv2D(10, (1, 1), padding='same'),  # Third convolutional layer with 10 filters
    Activation('relu'),
    Flatten(),
    Dense(100),  # Dense layer with 100 units
    Activation('relu'),
    # Dense(100),  # Additional Dense layer to make it 6 layers in total
    # Activation('relu'),
    Dense(1),  # Output layer for binary classification
    Activation('sigmoid')
])


model_1.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])
history_1 = model_1.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# C:\Users\FH-Deg\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8978 - loss: 0.3756 - val_accuracy: 0.8969 - val_loss: 0.2973
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.8974 - loss: 0.2946 - val_accuracy: 0.8969 - val_loss: 0.2917
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.8978 - loss: 0.2902 - val_accuracy: 0.8969 - val_loss: 0.2867
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9001 - loss: 0.2812 - val_accuracy: 0.8969 - val_loss: 0.2841
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8993 - loss: 0.2788 - val_accuracy: 0.8969 - val_loss: 0.2801

# %% [markdown]
# ### Probablistic outcome of classifer to pre-train policy network

# %%
probabilities = model_1.predict(x_train)
threshold = min(probabilities[y_train == 1])

# Convert probabilities to binary labels based on the threshold
predicted_labels = (probabilities >= threshold).astype(int)
clf_predicted_labels = predicted_labels.flatten().astype(int)

print("Classifer predicted labels distribution:", np.bincount(clf_predicted_labels))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step
# Classifer predicted labels distribution: [ 2110 57890]

# %%
# Policy-Network Model

class PolicyGradientNetwork:
    def __init__(self):
        self.model = self._create_model()
    
    def _create_model(self):
        model = Sequential([
            Conv2D(96, (3, 3), padding='same', input_shape=(28, 28, 1)),
            Activation('relu'),
            Conv2D(10, (3, 3), padding='same'),
            Activation('relu'),
            Flatten(),
            Dense(100),
            Activation('relu'),
            # Dense(100),  # Additional Dense layer
            # Activation('relu'),
            Dense(1),  # Softmax output for binary classification
            Activation('sigmoid') # Hard labeling
        ])
        return model
    
    def get_model(self):
        return self.model
    
    

policy_network = PolicyGradientNetwork()
pn_model = policy_network.get_model()

pn_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

# Fit the model with one-hot encoded labels
history_2 = pn_model.fit(x_train, clf_predicted_labels, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# C:\Users\FH-Deg\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9584 - loss: 0.2505 - val_accuracy: 0.9747 - val_loss: 0.0687
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - accuracy: 0.9789 - loss: 0.0580 - val_accuracy: 0.9827 - val_loss: 0.0470
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9848 - loss: 0.0396 - val_accuracy: 0.9855 - val_loss: 0.0388
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9877 - loss: 0.0334 - val_accuracy: 0.9855 - val_loss: 0.0354
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9892 - loss: 0.0288 - val_accuracy: 0.9881 - val_loss: 0.0315

# %%
probabilities = pn_model.predict(x_train)
threshold = min(probabilities[y_train == 1])

# Convert probabilities to binary labels based on the threshold
predicted_labels = (probabilities >= threshold).astype(int)
np_predicted_labels = predicted_labels.flatten().astype(int)

print("Classifer predicted labels distribution:", np.bincount(np_predicted_labels))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step
# Classifer predicted labels distribution: [ 1532 58468]

# %%
pn_model.predict(x_train)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step
# array([[0.99999994],
#        [0.9959101 ],
#        [0.99999917],
#        ...,
#        [0.9999998 ],
#        [0.9848314 ],
#        [0.99967486]], dtype=float32)

# %% [markdown]
# ## Interactive learning

# %%
import gym
from gym import spaces
import numpy as np

class CustomEnv(gym.Env):
    def __init__(self, x_train, labels, mnist_data, model, threshold=0.5):
        super(CustomEnv, self).__init__()
        # self.mnist_data = mnist_data
        self.model = model
        self.x_train=x_test
        self.labels=labels
        self.threshold = threshold
        self.current_index = 0
        
        self.action_space = spaces.Discrete(2)  # Actions: 0 or 1
        self.observation_space = spaces.Box(low=0, high=255, shape=(28, 28, 1), dtype=np.uint8)

    def step(self, action):
        x_fv, label = self._get_next_instance()
        # img, label = self._get_next_image()
        
        predicted_prob = self.model.predict(x_fv)[0][0]
        print(f"CustomEnv probability: {predicted_prob}")
        predicted_label = 1 if predicted_prob >= self.threshold else 0
        print(f"CustomEnv predicted_label: {predicted_label}")
        
        # reward = self._get_reward(label, predicted_label, predicted_prob)
        
        self.current_step += 1
        done = self.current_step >= len(self.mnist_data)
        
        # return img, reward, done, {}
        # return x_fv, reward, done, {}
        return x_fv, predicted_label, done, {}
    
    def _get_next_instance(self):
        # Ensure the current index is within the bounds of the dataset
        if self.current_index < len(self.x_train):
            x_fv = self.x_train[self.current_index]
            label = self.labels[self.current_index]
            self.current_index += 1  # Move to the next instance
            return x_fv, label
        else:
            # Handle the end of the dataset; you might want to reset or take another action
            return None, None

    def reset(self):
        self.current_step = 0
        self.current_index=0
        # return self._get_next_image()[0]
        return self._get_next_instance()[0]

    # def _get_next_image(self):
    #     img, label = self.mnist_data[self.current_step]
    #     return img, label

    # def _get_reward(self, true_label, predicted_label, predicted_prob):
    #     if predicted_label == 1 and true_label == 1:

    #     if true_label == predicted_label:
    #         return predicted_prob
    #     else:
    #         return 1 - predicted_prob
        
    #     if predicted_label == 1 and true_label == 1:  # Fraud (positive class)
    #         if y_hat >= 0.5:  # Predicted probability is greater than or equal to threshold
    #             return self.y[self.current_index]
    #         else:
    #             return 1 - self.y[self.current_index]
    #     else:  # Not-Fraud (negative class)
    #         return self.y[self.current_index]

    # def render(self, mode='human', close=False):
    #     pass  # Add rendering logic if needed

# %%
# env = CustomEnv(x_train=x_train, labels=y_train, model=pn_model)
# # Create an instance of CustomEnv
# # env = CustomEnv(balanced_df)

# # Reset the environment to its initial state
# observation = env.reset()
# print(f"cust OBser: {observation}")

# %%
import tensorflow as tf
import numpy as np

class Agent:
    def __init__(self, model, target_model, alpha=0.00001, gamma=0.99):
        self.gamma = gamma  # Discount factor
        self.lr = alpha  # Learning rate
        self.model = model  # Policy model
        self.target_model = target_model # target policy model
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []

    # def choose_action(self, state):
    #     # Convert states to a tensor
    #     state = state.reshape(1, 28, 28, 1)
    #     state = tf.convert_to_tensor(state, dtype=tf.float32)
        
    #     # Predict the probabilities for actions
    #     probabilities = self.model(state)
        
    #     # Sample actions based on these probabilities
    #     action_sampler = tfp.distributions.Bernoulli(probs=probabilities)
    #     actions = action_sampler.sample()
        
    #     return actions.numpy(), probabilities

    def choose_action(self, state):
        # Use the target model for stable decision making
        state = tf.convert_to_tensor([state], dtype=tf.float32)
        probabilities = self.target_model(state)
        action_sampler = tfp.distributions.Bernoulli(probs=probabilities, dtype=tf.float32)
        action = action_sampler.sample()
        return action.numpy()[0, 0], probabilities.numpy()[0, 0]

    def store_transition(self, state, action, reward):
        self.state_memory.append(state)
        self.action_memory.append(action)
        self.reward_memory.append(reward)

    def learn(self):
        actions = np.array(self.action_memory)
        rewards = np.array(self.reward_memory)
        states = np.array(self.state_memory)

        # Calculate discounted rewards
        G = np.zeros_like(rewards)
        for t in range(len(rewards)):
            G_sum = 0
            discount = 1
            for k in range(t, len(rewards)):
                G_sum += rewards[k] * discount
                discount *= self.gamma
            G[t] = G_sum

        # Updating policy
        with tf.GradientTape() as tape:
            loss = 0
            for idx, (g, state) in enumerate(zip(G, states)):
                state = tf.convert_to_tensor([state], dtype=tf.float32)
                probs = self.model(state, training=True)
                action_probs = tfp.distributions.Bernoulli(probs=probs)
                log_prob = action_probs.log_prob(actions[idx])
                loss += -g * tf.reduce_sum(log_prob)

        gradients = tape.gradient(loss, self.model.trainable_variables)
        self.model.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

        # Clear memory
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []

# %%
# Clone policy model for stable target policy
target_policy_model = tf.keras.models.clone_model(pn_model)
target_policy_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = {
    'epoch_loss': [],
    'epoch_accuracy': [],
    'batch_loss': [],
    'batch_accuracy': [],
    'predictions': [],
    'rewards': [],
    'thresholds': []
}

# %%
agent = Agent(pn_model,target_model=target_policy_model, alpha=0.00001, gamma=0.99)
# Example parameters
n_epochs = 300
# n_epochs = 10
batch_size = 128 # You can adjust the batch size as needed

def shuffle_data(x_train, y_train, s):
    indices = np.arange(len(x_train))
    np.random.shuffle(indices)
    return x_train[indices], y_train[indices], s[indices]

def create_mini_batches(x_train, y_train, s, batch_size):
    for start_idx in range(0, len(x_train) - batch_size + 1, batch_size):
        excerpt = slice(start_idx, start_idx + batch_size)
        yield x_train[excerpt], y_train[excerpt], s[excerpt]

def calculate_threshold(clf_probabilities, y_batch):
    # Identify indices of positive examples
    positive_indices = (y_batch == 1)
    
    # Calculate threshmin from positive examples
    if np.any(positive_indices):
        threshmin = np.min(clf_probabilities[positive_indices])
    else:
        threshmin = 0  # Default value if no positive examples are present

    # Identify U0 - samples with predictions >= threshmin
    U0_indices = (clf_probabilities >= threshmin)
    
    # Calculate the final threshold using Equation 5
    if np.any(U0_indices):
        threshold = np.mean(clf_probabilities[U0_indices])
    else:
        threshold = threshmin  # Use threshmin if no samples meet the U0 criteria

    return threshold


for epoch in range(1, n_epochs + 1):
    # variables for epoch-wise aggregation
    epoch_losses = []
    epoch_accuracies = []
    epoch_rewards = []
    x_train_shuffled, y_train_shuffled, s_shuffled = shuffle_data(x_train, y_train, s)
    
    for x_batch, y_batch, s_batch in create_mini_batches(x_train_shuffled, y_train_shuffled, s_shuffled, batch_size):
        # 
        # probabilities = pn_model.predict(x_batch)
        # # print(f"Probabilities = {probabilities}")
        # threshold = min(probabilities[y_batch == 1])
        # print(f"Threshold = {threshold}")
        # predicted_labels = (probabilities >= threshold).astype(int)
        # pn_predicted_labels = predicted_labels.flatten().astype(int)
        
        # actions = np.array([target_policy_model.predict(x.reshape(1, 28, 28, 1)).argmax() for x in x_batch])

        actions = []
        probabilities = []
        for x in x_batch:
            action, probability  = agent.choose_action(x)
            actions.append(action)
            probabilities.append(probability)
        actions = np.array(actions)

        # actions = []
        # probabilities = []
        # for x in x_batch:
        #     action, probability  = agent.choose_action(x)
        #     actions.append(action)
        #     probabilities.append(probability)
        # actions = np.array(actions)

        # batch_loss, batch_acc  = model_1.fit(x_batch, actions, epochs=1, batch_size=len(x_batch), validation_split=0.2)
        # history['batch_loss'].append(batch_loss)
        # history['batch_accuracy'].append(batch_acc)
        batch_history = model_1.fit(x_batch, actions, epochs=1, batch_size=len(x_batch), validation_split=0.2)
        batch_loss = batch_history.history['loss'][0]  # Extract loss for the first (and only) epoch
        batch_acc = batch_history.history['accuracy'][0]  # Extract accuracy for the first (and only) epoch
        
        history['batch_loss'].append(batch_loss)
        history['batch_accuracy'].append(batch_acc)

        clf_probabilities = model_1.predict(x_batch)
        threshold = calculate_threshold(clf_probabilities, y_batch)
        history['thresholds'].append(threshold)
        
        
        rewards = []
        for prob, actual in zip(clf_probabilities, y_batch):
            if actual == 1 or (actual == 0 and prob >= threshold):
                reward = prob
            else:
                reward = 1 - prob
            rewards.append(reward)
        
        history['rewards'].append(rewards)
        # print("reward Claculated")

        epoch_losses.append(batch_loss)
        epoch_accuracies.append(batch_acc)
        epoch_rewards.extend(rewards)

        # Store transitions and learn from them
        for state, action, reward in zip(x_batch, actions, rewards):
        # for state, action, reward in zip(x_batch, pn_predicted_labels, rewards):
            agent.store_transition(state, action, reward)
        agent.learn()
        # print("Agent learned")
        
    history['epoch_loss'].append(np.mean(epoch_losses))
    history['epoch_accuracy'].append(np.mean(epoch_accuracies))
    
    if epoch % 3 == 0:  # Every 3 epochs
        print("Updating target policy...")
        target_policy_model.set_weights(pn_model.get_weights())

    
import pickle
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history, f)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4314 - loss: 0.9195 - val_accuracy: 0.6154 - val_loss: 0.7018
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5686 - loss: 0.7938 - val_accuracy: 0.6538 - val_loss: 0.6777
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5000 - loss: 0.8108 - val_accuracy: 0.4615 - val_loss: 0.7690
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5098 - loss: 0.7750 - val_accuracy: 0.5385 - val_loss: 0.8423
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.4902 - loss: 0.7318 - val_accuracy: 0.6154 - val_loss: 0.5959
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4608 - loss: 0.7928 - val_accuracy: 0.5000 - val_loss: 0.8096
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5000 - loss: 0.7011 - val_accuracy: 0.4231 - val_loss: 0.7500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5294 - loss: 0.7295 - val_accuracy: 0.5769 - val_loss: 0.6635
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5098 - loss: 0.7099 - val_accuracy: 0.5385 - val_loss: 0.7151
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.5392 - loss: 0.6991 - val_accuracy: 0.5769 - val_loss: 0.6936
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4706 - loss: 0.7337 - val_accuracy: 0.5000 - val_loss: 0.7002
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.3824 - loss: 0.8238 - val_accuracy: 0.6154 - val_loss: 0.6745
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.5588 - loss: 0.7239 - val_accuracy: 0.4231 - val_loss: 0.7330
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5196 - loss: 0.7118 - val_accuracy: 0.5000 - val_loss: 0.6996
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5000 - loss: 0.7705 - val_accuracy: 0.6154 - val_loss: 0.6933
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5392 - loss: 0.7185 - val_accuracy: 0.4615 - val_loss: 0.8053
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4902 - loss: 0.7327 - val_accuracy: 0.6154 - val_loss: 0.6401
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5392 - loss: 0.7008 - val_accuracy: 0.3846 - val_loss: 0.7600
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5686 - loss: 0.6939 - val_accuracy: 0.4615 - val_loss: 0.7530
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5000 - loss: 0.7144 - val_accuracy: 0.3077 - val_loss: 0.8694
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5098 - loss: 0.7059 - val_accuracy: 0.5385 - val_loss: 0.7818
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.4216 - loss: 0.7653 - val_accuracy: 0.3462 - val_loss: 0.8239
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5490 - loss: 0.7158 - val_accuracy: 0.5000 - val_loss: 0.7524
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5392 - loss: 0.7185 - val_accuracy: 0.3462 - val_loss: 0.8404
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4510 - loss: 0.7768 - val_accuracy: 0.5000 - val_loss: 0.7438
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5196 - loss: 0.7335 - val_accuracy: 0.4231 - val_loss: 0.7589
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5294 - loss: 0.7145 - val_accuracy: 0.4615 - val_loss: 0.7594
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4510 - loss: 0.7514 - val_accuracy: 0.4615 - val_loss: 0.8175
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5196 - loss: 0.7339 - val_accuracy: 0.5385 - val_loss: 0.7733
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5686 - loss: 0.7173 - val_accuracy: 0.5000 - val_loss: 0.7064
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5000 - loss: 0.7282 - val_accuracy: 0.6154 - val_loss: 0.6360
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.4804 - loss: 0.7482 - val_accuracy: 0.5000 - val_loss: 0.7472
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3922 - loss: 0.7596 - val_accuracy: 0.5385 - val_loss: 0.7177
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5098 - loss: 0.7114 - val_accuracy: 0.6154 - val_loss: 0.6726
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4804 - loss: 0.7309 - val_accuracy: 0.5769 - val_loss: 0.6465
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4706 - loss: 0.7185 - val_accuracy: 0.5000 - val_loss: 0.6910
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5784 - loss: 0.6788 - val_accuracy: 0.5385 - val_loss: 0.7053
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4314 - loss: 0.7267 - val_accuracy: 0.5385 - val_loss: 0.6768
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5784 - loss: 0.6819 - val_accuracy: 0.5385 - val_loss: 0.6907
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5392 - loss: 0.6938 - val_accuracy: 0.5000 - val_loss: 0.6860
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4706 - loss: 0.7361 - val_accuracy: 0.4615 - val_loss: 0.7019
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.6471 - loss: 0.6426 - val_accuracy: 0.5769 - val_loss: 0.6945
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5784 - loss: 0.6876 - val_accuracy: 0.4231 - val_loss: 0.7212
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5098 - loss: 0.7022 - val_accuracy: 0.6154 - val_loss: 0.6664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5098 - loss: 0.7265 - val_accuracy: 0.4231 - val_loss: 0.7591
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5098 - loss: 0.7082 - val_accuracy: 0.4615 - val_loss: 0.6879
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5294 - loss: 0.6959 - val_accuracy: 0.6154 - val_loss: 0.6712
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4804 - loss: 0.7059 - val_accuracy: 0.5000 - val_loss: 0.6933
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.4804 - loss: 0.7196 - val_accuracy: 0.4231 - val_loss: 0.7375
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4412 - loss: 0.7063 - val_accuracy: 0.5000 - val_loss: 0.7433
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5000 - loss: 0.6990 - val_accuracy: 0.5385 - val_loss: 0.6998
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.5686 - loss: 0.7026 - val_accuracy: 0.6154 - val_loss: 0.6517
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5196 - loss: 0.7008 - val_accuracy: 0.5769 - val_loss: 0.6740
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.4608 - loss: 0.7152 - val_accuracy: 0.5000 - val_loss: 0.6909
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5294 - loss: 0.6971 - val_accuracy: 0.4615 - val_loss: 0.7200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4706 - loss: 0.7295 - val_accuracy: 0.5385 - val_loss: 0.7096
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4314 - loss: 0.7321 - val_accuracy: 0.5385 - val_loss: 0.6796
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.4706 - loss: 0.7197 - val_accuracy: 0.6154 - val_loss: 0.6797
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5392 - loss: 0.6724 - val_accuracy: 0.6154 - val_loss: 0.6675
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5000 - loss: 0.7076 - val_accuracy: 0.6154 - val_loss: 0.6738
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4804 - loss: 0.7119 - val_accuracy: 0.3462 - val_loss: 0.7390
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4706 - loss: 0.7329 - val_accuracy: 0.5000 - val_loss: 0.6962
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5000 - loss: 0.7027 - val_accuracy: 0.5769 - val_loss: 0.6817
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4118 - loss: 0.7338 - val_accuracy: 0.2692 - val_loss: 0.7856
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4510 - loss: 0.7221 - val_accuracy: 0.4615 - val_loss: 0.6885
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.4608 - loss: 0.7377 - val_accuracy: 0.3846 - val_loss: 0.7232
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4706 - loss: 0.7140 - val_accuracy: 0.6154 - val_loss: 0.6719
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4804 - loss: 0.7168 - val_accuracy: 0.3846 - val_loss: 0.7730
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5490 - loss: 0.6878 - val_accuracy: 0.6538 - val_loss: 0.6608
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.5000 - loss: 0.6946 - val_accuracy: 0.6538 - val_loss: 0.6579
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4314 - loss: 0.7191 - val_accuracy: 0.4615 - val_loss: 0.7418
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4608 - loss: 0.7177 - val_accuracy: 0.5000 - val_loss: 0.6992
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4804 - loss: 0.7049 - val_accuracy: 0.5385 - val_loss: 0.7114
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5392 - loss: 0.6888 - val_accuracy: 0.5769 - val_loss: 0.6882
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5098 - loss: 0.6909 - val_accuracy: 0.2692 - val_loss: 0.7946
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.4902 - loss: 0.7320 - val_accuracy: 0.5000 - val_loss: 0.6859
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.5392 - loss: 0.6915 - val_accuracy: 0.7308 - val_loss: 0.6435
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4510 - loss: 0.7178 - val_accuracy: 0.3846 - val_loss: 0.7237
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5196 - loss: 0.6962 - val_accuracy: 0.3846 - val_loss: 0.7363
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5098 - loss: 0.7024 - val_accuracy: 0.5385 - val_loss: 0.7071
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4510 - loss: 0.7304 - val_accuracy: 0.6923 - val_loss: 0.6892
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4118 - loss: 0.7097 - val_accuracy: 0.5385 - val_loss: 0.6926
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.4608 - loss: 0.7129 - val_accuracy: 0.4615 - val_loss: 0.7186
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4902 - loss: 0.7003 - val_accuracy: 0.5000 - val_loss: 0.7171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5490 - loss: 0.6899 - val_accuracy: 0.5385 - val_loss: 0.6689
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5196 - loss: 0.6963 - val_accuracy: 0.5385 - val_loss: 0.6791
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5196 - loss: 0.6873 - val_accuracy: 0.5385 - val_loss: 0.7101
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4902 - loss: 0.7176 - val_accuracy: 0.5000 - val_loss: 0.7298
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.3627 - loss: 0.7272 - val_accuracy: 0.4615 - val_loss: 0.7080
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5294 - loss: 0.7062 - val_accuracy: 0.5769 - val_loss: 0.6987
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5098 - loss: 0.6908 - val_accuracy: 0.6923 - val_loss: 0.6566
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4314 - loss: 0.7233 - val_accuracy: 0.5385 - val_loss: 0.6755
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5196 - loss: 0.7042 - val_accuracy: 0.3846 - val_loss: 0.7105
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5196 - loss: 0.6967 - val_accuracy: 0.4615 - val_loss: 0.7285
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5196 - loss: 0.6984 - val_accuracy: 0.6538 - val_loss: 0.6789
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5490 - loss: 0.6844 - val_accuracy: 0.4231 - val_loss: 0.7083
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5588 - loss: 0.6858 - val_accuracy: 0.4615 - val_loss: 0.7298
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5196 - loss: 0.7127 - val_accuracy: 0.5000 - val_loss: 0.6951
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5000 - loss: 0.7001 - val_accuracy: 0.5385 - val_loss: 0.6910
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4510 - loss: 0.7123 - val_accuracy: 0.5385 - val_loss: 0.6912
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4510 - loss: 0.7260 - val_accuracy: 0.7308 - val_loss: 0.6408
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.4706 - loss: 0.7117 - val_accuracy: 0.5385 - val_loss: 0.7025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5000 - loss: 0.7106 - val_accuracy: 0.6154 - val_loss: 0.6839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4706 - loss: 0.7135 - val_accuracy: 0.5769 - val_loss: 0.6769
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5686 - loss: 0.7023 - val_accuracy: 0.4231 - val_loss: 0.7248
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5490 - loss: 0.6792 - val_accuracy: 0.5000 - val_loss: 0.6693
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5588 - loss: 0.6828 - val_accuracy: 0.4615 - val_loss: 0.7000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4608 - loss: 0.7005 - val_accuracy: 0.5000 - val_loss: 0.7070
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5392 - loss: 0.6881 - val_accuracy: 0.4231 - val_loss: 0.7188
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4706 - loss: 0.7019 - val_accuracy: 0.3846 - val_loss: 0.7143
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5686 - loss: 0.6882 - val_accuracy: 0.3077 - val_loss: 0.7426
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5000 - loss: 0.6891 - val_accuracy: 0.5000 - val_loss: 0.6933
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5000 - loss: 0.7170 - val_accuracy: 0.5385 - val_loss: 0.6663
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5490 - loss: 0.6764 - val_accuracy: 0.6154 - val_loss: 0.6947
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5392 - loss: 0.6939 - val_accuracy: 0.6154 - val_loss: 0.6744
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5294 - loss: 0.6945 - val_accuracy: 0.4615 - val_loss: 0.6902
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.5686 - loss: 0.6852 - val_accuracy: 0.6538 - val_loss: 0.6579
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5098 - loss: 0.6969 - val_accuracy: 0.6538 - val_loss: 0.6855
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.4216 - loss: 0.7209 - val_accuracy: 0.5385 - val_loss: 0.6549
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5686 - loss: 0.6909 - val_accuracy: 0.5769 - val_loss: 0.6889
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4216 - loss: 0.7351 - val_accuracy: 0.6154 - val_loss: 0.6670
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4804 - loss: 0.7035 - val_accuracy: 0.6923 - val_loss: 0.6597
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5000 - loss: 0.6979 - val_accuracy: 0.5000 - val_loss: 0.7021
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5196 - loss: 0.6992 - val_accuracy: 0.3462 - val_loss: 0.7178
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.4804 - loss: 0.6962 - val_accuracy: 0.5769 - val_loss: 0.6790
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5196 - loss: 0.6901 - val_accuracy: 0.5000 - val_loss: 0.6958
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5098 - loss: 0.7010 - val_accuracy: 0.5769 - val_loss: 0.6675
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5490 - loss: 0.6913 - val_accuracy: 0.3462 - val_loss: 0.7203
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5784 - loss: 0.6847 - val_accuracy: 0.4615 - val_loss: 0.7097
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4804 - loss: 0.6990 - val_accuracy: 0.4231 - val_loss: 0.7086
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5000 - loss: 0.7010 - val_accuracy: 0.5769 - val_loss: 0.6815
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5196 - loss: 0.7086 - val_accuracy: 0.4231 - val_loss: 0.7389
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5784 - loss: 0.6910 - val_accuracy: 0.5385 - val_loss: 0.6839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4706 - loss: 0.6954 - val_accuracy: 0.5000 - val_loss: 0.7039
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4510 - loss: 0.6954 - val_accuracy: 0.5000 - val_loss: 0.7305
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.4020 - loss: 0.7324 - val_accuracy: 0.4231 - val_loss: 0.7059
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4804 - loss: 0.6964 - val_accuracy: 0.3846 - val_loss: 0.7282
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4608 - loss: 0.7137 - val_accuracy: 0.4231 - val_loss: 0.7210
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5392 - loss: 0.6851 - val_accuracy: 0.5000 - val_loss: 0.7019
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4216 - loss: 0.7098 - val_accuracy: 0.5769 - val_loss: 0.6994
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4706 - loss: 0.6952 - val_accuracy: 0.5000 - val_loss: 0.6886
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4510 - loss: 0.7168 - val_accuracy: 0.5000 - val_loss: 0.6904
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6078 - loss: 0.6805 - val_accuracy: 0.5000 - val_loss: 0.7126
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5098 - loss: 0.7099 - val_accuracy: 0.5769 - val_loss: 0.7001
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4804 - loss: 0.7151 - val_accuracy: 0.6154 - val_loss: 0.6773
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5196 - loss: 0.7036 - val_accuracy: 0.3077 - val_loss: 0.7598
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4608 - loss: 0.7181 - val_accuracy: 0.6538 - val_loss: 0.6434
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5294 - loss: 0.6912 - val_accuracy: 0.6538 - val_loss: 0.6672
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5392 - loss: 0.6887 - val_accuracy: 0.5769 - val_loss: 0.7093
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5490 - loss: 0.6969 - val_accuracy: 0.5769 - val_loss: 0.6932
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5000 - loss: 0.6981 - val_accuracy: 0.5769 - val_loss: 0.6684
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4608 - loss: 0.7183 - val_accuracy: 0.5769 - val_loss: 0.6769
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4510 - loss: 0.7161 - val_accuracy: 0.4615 - val_loss: 0.7104
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5980 - loss: 0.6909 - val_accuracy: 0.5769 - val_loss: 0.6793
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4412 - loss: 0.7032 - val_accuracy: 0.4231 - val_loss: 0.7332
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5686 - loss: 0.6811 - val_accuracy: 0.3462 - val_loss: 0.7067
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4902 - loss: 0.6916 - val_accuracy: 0.5000 - val_loss: 0.7037
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5000 - loss: 0.6797 - val_accuracy: 0.5385 - val_loss: 0.6847
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.6078 - loss: 0.6788 - val_accuracy: 0.5000 - val_loss: 0.6931
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5196 - loss: 0.6962 - val_accuracy: 0.4231 - val_loss: 0.7319
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4804 - loss: 0.7006 - val_accuracy: 0.6154 - val_loss: 0.6658
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5196 - loss: 0.6982 - val_accuracy: 0.3462 - val_loss: 0.7191
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5098 - loss: 0.6969 - val_accuracy: 0.6923 - val_loss: 0.6839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4804 - loss: 0.7033 - val_accuracy: 0.5385 - val_loss: 0.7167
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.4804 - loss: 0.6952 - val_accuracy: 0.2692 - val_loss: 0.7199
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5098 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.7057
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4608 - loss: 0.6995 - val_accuracy: 0.5000 - val_loss: 0.7177
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.4706 - loss: 0.7150 - val_accuracy: 0.3077 - val_loss: 0.7414
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4902 - loss: 0.6976 - val_accuracy: 0.6538 - val_loss: 0.6782
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5000 - loss: 0.7037 - val_accuracy: 0.4615 - val_loss: 0.6868
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5098 - loss: 0.6927 - val_accuracy: 0.5769 - val_loss: 0.6772
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5196 - loss: 0.6966 - val_accuracy: 0.5000 - val_loss: 0.7059
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.5098 - loss: 0.6981 - val_accuracy: 0.5385 - val_loss: 0.6945
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.5686 - loss: 0.6840 - val_accuracy: 0.3846 - val_loss: 0.7329
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5000 - loss: 0.6981 - val_accuracy: 0.5000 - val_loss: 0.6919
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5294 - loss: 0.7019 - val_accuracy: 0.2692 - val_loss: 0.7091
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5098 - loss: 0.7006 - val_accuracy: 0.6154 - val_loss: 0.6656
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5686 - loss: 0.6787 - val_accuracy: 0.4231 - val_loss: 0.7155
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5294 - loss: 0.6961 - val_accuracy: 0.6923 - val_loss: 0.6701
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5490 - loss: 0.6817 - val_accuracy: 0.5385 - val_loss: 0.6950
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4216 - loss: 0.7128 - val_accuracy: 0.6538 - val_loss: 0.6623
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5490 - loss: 0.6915 - val_accuracy: 0.4231 - val_loss: 0.7136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5294 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6804
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4608 - loss: 0.7006 - val_accuracy: 0.5385 - val_loss: 0.6778
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5000 - loss: 0.6928 - val_accuracy: 0.5769 - val_loss: 0.7069
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5294 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.6855
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4706 - loss: 0.6976 - val_accuracy: 0.3462 - val_loss: 0.7382
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4706 - loss: 0.7217 - val_accuracy: 0.3846 - val_loss: 0.7296
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5196 - loss: 0.6867 - val_accuracy: 0.4231 - val_loss: 0.7188
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4902 - loss: 0.7027 - val_accuracy: 0.6154 - val_loss: 0.6572
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4902 - loss: 0.6964 - val_accuracy: 0.3846 - val_loss: 0.7123
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5686 - loss: 0.6864 - val_accuracy: 0.3462 - val_loss: 0.7073
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4118 - loss: 0.7166 - val_accuracy: 0.4615 - val_loss: 0.6737
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5098 - loss: 0.6933 - val_accuracy: 0.4615 - val_loss: 0.7012
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5392 - loss: 0.6807 - val_accuracy: 0.5000 - val_loss: 0.7023
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4902 - loss: 0.7058 - val_accuracy: 0.3077 - val_loss: 0.7159
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.5196 - loss: 0.7020 - val_accuracy: 0.6538 - val_loss: 0.6874
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5196 - loss: 0.6945 - val_accuracy: 0.3846 - val_loss: 0.7081
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4706 - loss: 0.7047 - val_accuracy: 0.4231 - val_loss: 0.7364
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5392 - loss: 0.6839 - val_accuracy: 0.5769 - val_loss: 0.6988
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5000 - loss: 0.6989 - val_accuracy: 0.5769 - val_loss: 0.7001
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4902 - loss: 0.7025 - val_accuracy: 0.6923 - val_loss: 0.6507
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4608 - loss: 0.7107 - val_accuracy: 0.5769 - val_loss: 0.6900
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.4216 - loss: 0.6989 - val_accuracy: 0.3462 - val_loss: 0.7343
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5490 - loss: 0.6955 - val_accuracy: 0.5385 - val_loss: 0.7219
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5098 - loss: 0.6956 - val_accuracy: 0.3846 - val_loss: 0.7205
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4020 - loss: 0.7178 - val_accuracy: 0.6154 - val_loss: 0.6717
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5392 - loss: 0.7031 - val_accuracy: 0.6154 - val_loss: 0.6785
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5686 - loss: 0.6807 - val_accuracy: 0.4231 - val_loss: 0.7033
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5000 - loss: 0.7018 - val_accuracy: 0.6923 - val_loss: 0.6773
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.4804 - loss: 0.7091 - val_accuracy: 0.5385 - val_loss: 0.6977
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5686 - loss: 0.6898 - val_accuracy: 0.5000 - val_loss: 0.7030
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5392 - loss: 0.7014 - val_accuracy: 0.4615 - val_loss: 0.7068
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5588 - loss: 0.6888 - val_accuracy: 0.6154 - val_loss: 0.6697
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4706 - loss: 0.7015 - val_accuracy: 0.5385 - val_loss: 0.7059
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5098 - loss: 0.6915 - val_accuracy: 0.5385 - val_loss: 0.7202
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5000 - loss: 0.7064 - val_accuracy: 0.5385 - val_loss: 0.6755
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.4020 - loss: 0.7064 - val_accuracy: 0.4231 - val_loss: 0.6905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5392 - loss: 0.6931 - val_accuracy: 0.5769 - val_loss: 0.6884
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5490 - loss: 0.6905 - val_accuracy: 0.5000 - val_loss: 0.7007
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5490 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.7031
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5392 - loss: 0.6885 - val_accuracy: 0.2692 - val_loss: 0.7289
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5588 - loss: 0.6914 - val_accuracy: 0.4231 - val_loss: 0.7129
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5490 - loss: 0.6880 - val_accuracy: 0.4231 - val_loss: 0.7054
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5098 - loss: 0.7001 - val_accuracy: 0.4231 - val_loss: 0.7136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5294 - loss: 0.7021 - val_accuracy: 0.3462 - val_loss: 0.7196
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5392 - loss: 0.6954 - val_accuracy: 0.5000 - val_loss: 0.6964
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5000 - loss: 0.6927 - val_accuracy: 0.5769 - val_loss: 0.6833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5392 - loss: 0.6953 - val_accuracy: 0.1538 - val_loss: 0.7267
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5294 - loss: 0.6910 - val_accuracy: 0.5385 - val_loss: 0.6866
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4804 - loss: 0.6999 - val_accuracy: 0.5769 - val_loss: 0.6691
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5000 - loss: 0.7060 - val_accuracy: 0.2692 - val_loss: 0.7336
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4510 - loss: 0.7048 - val_accuracy: 0.4231 - val_loss: 0.7542
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5490 - loss: 0.6948 - val_accuracy: 0.3846 - val_loss: 0.7015
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.5784 - loss: 0.6831 - val_accuracy: 0.5385 - val_loss: 0.6981
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.5098 - loss: 0.6911 - val_accuracy: 0.6538 - val_loss: 0.6617
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4412 - loss: 0.7126 - val_accuracy: 0.5385 - val_loss: 0.6848
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5196 - loss: 0.6963 - val_accuracy: 0.5000 - val_loss: 0.6871
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4902 - loss: 0.7019 - val_accuracy: 0.4615 - val_loss: 0.6789
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4804 - loss: 0.6923 - val_accuracy: 0.5000 - val_loss: 0.7050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4314 - loss: 0.7234 - val_accuracy: 0.5769 - val_loss: 0.6872
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5000 - loss: 0.7052 - val_accuracy: 0.3077 - val_loss: 0.7450
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5294 - loss: 0.6966 - val_accuracy: 0.6154 - val_loss: 0.6728
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4902 - loss: 0.6990 - val_accuracy: 0.6538 - val_loss: 0.6806
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5588 - loss: 0.6770 - val_accuracy: 0.4615 - val_loss: 0.6829
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4118 - loss: 0.7178 - val_accuracy: 0.3846 - val_loss: 0.7010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4706 - loss: 0.6952 - val_accuracy: 0.6538 - val_loss: 0.6707
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5490 - loss: 0.6934 - val_accuracy: 0.5385 - val_loss: 0.6967
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5000 - loss: 0.6896 - val_accuracy: 0.2692 - val_loss: 0.7244
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4804 - loss: 0.7130 - val_accuracy: 0.5000 - val_loss: 0.6895
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6176 - loss: 0.6803 - val_accuracy: 0.5769 - val_loss: 0.7043
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4902 - loss: 0.6904 - val_accuracy: 0.6538 - val_loss: 0.6842
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.5882 - loss: 0.6946 - val_accuracy: 0.4231 - val_loss: 0.6992
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5098 - loss: 0.6915 - val_accuracy: 0.4231 - val_loss: 0.6949
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4510 - loss: 0.7016 - val_accuracy: 0.4615 - val_loss: 0.6901
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5392 - loss: 0.6851 - val_accuracy: 0.6538 - val_loss: 0.6796
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4510 - loss: 0.7052 - val_accuracy: 0.5385 - val_loss: 0.6778
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.5588 - loss: 0.6774 - val_accuracy: 0.5000 - val_loss: 0.7006
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5196 - loss: 0.6977 - val_accuracy: 0.3462 - val_loss: 0.7268
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5098 - loss: 0.7009 - val_accuracy: 0.4231 - val_loss: 0.7102
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4118 - loss: 0.7058 - val_accuracy: 0.5385 - val_loss: 0.7008
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.6176 - loss: 0.6894 - val_accuracy: 0.5000 - val_loss: 0.6923
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5196 - loss: 0.6953 - val_accuracy: 0.4231 - val_loss: 0.7138
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5294 - loss: 0.6879 - val_accuracy: 0.5000 - val_loss: 0.7036
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4510 - loss: 0.7065 - val_accuracy: 0.5769 - val_loss: 0.6900
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5294 - loss: 0.6917 - val_accuracy: 0.4231 - val_loss: 0.7093
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5098 - loss: 0.6965 - val_accuracy: 0.5000 - val_loss: 0.7014
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.4216 - loss: 0.7032 - val_accuracy: 0.5769 - val_loss: 0.6805
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.4608 - loss: 0.6995 - val_accuracy: 0.3462 - val_loss: 0.7046
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5000 - loss: 0.7076 - val_accuracy: 0.4615 - val_loss: 0.7074
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5392 - loss: 0.6919 - val_accuracy: 0.4615 - val_loss: 0.7072
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4510 - loss: 0.7001 - val_accuracy: 0.5000 - val_loss: 0.6928
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4608 - loss: 0.7016 - val_accuracy: 0.5000 - val_loss: 0.6840
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5000 - loss: 0.6981 - val_accuracy: 0.5385 - val_loss: 0.6733
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.4804 - loss: 0.6994 - val_accuracy: 0.6154 - val_loss: 0.6713
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4706 - loss: 0.7016 - val_accuracy: 0.5769 - val_loss: 0.6756
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5882 - loss: 0.6768 - val_accuracy: 0.5769 - val_loss: 0.6827
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5588 - loss: 0.6781 - val_accuracy: 0.7692 - val_loss: 0.6481
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.6275 - loss: 0.6732 - val_accuracy: 0.5769 - val_loss: 0.6908
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5686 - loss: 0.6920 - val_accuracy: 0.4615 - val_loss: 0.7090
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5196 - loss: 0.6878 - val_accuracy: 0.5385 - val_loss: 0.7062
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4706 - loss: 0.6949 - val_accuracy: 0.5000 - val_loss: 0.7096
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4804 - loss: 0.6994 - val_accuracy: 0.3462 - val_loss: 0.7156
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4902 - loss: 0.6997 - val_accuracy: 0.5769 - val_loss: 0.7000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5098 - loss: 0.6884 - val_accuracy: 0.4615 - val_loss: 0.7035
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5490 - loss: 0.6910 - val_accuracy: 0.3077 - val_loss: 0.7285
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4902 - loss: 0.7032 - val_accuracy: 0.4231 - val_loss: 0.7118
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5098 - loss: 0.6959 - val_accuracy: 0.5000 - val_loss: 0.6848
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5686 - loss: 0.6933 - val_accuracy: 0.5385 - val_loss: 0.6674
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5588 - loss: 0.6955 - val_accuracy: 0.5385 - val_loss: 0.6837
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5882 - loss: 0.6858 - val_accuracy: 0.6154 - val_loss: 0.6873
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.4314 - loss: 0.7074 - val_accuracy: 0.6923 - val_loss: 0.6557
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5588 - loss: 0.6853 - val_accuracy: 0.5385 - val_loss: 0.6907
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4608 - loss: 0.6999 - val_accuracy: 0.5000 - val_loss: 0.7055
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5196 - loss: 0.6943 - val_accuracy: 0.3846 - val_loss: 0.7152
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5196 - loss: 0.6880 - val_accuracy: 0.3846 - val_loss: 0.6904
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4902 - loss: 0.7035 - val_accuracy: 0.6154 - val_loss: 0.6821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5098 - loss: 0.6928 - val_accuracy: 0.5769 - val_loss: 0.6907
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5882 - loss: 0.6836 - val_accuracy: 0.5769 - val_loss: 0.7003
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4706 - loss: 0.7086 - val_accuracy: 0.5769 - val_loss: 0.6717
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4706 - loss: 0.7025 - val_accuracy: 0.5769 - val_loss: 0.6740
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5490 - loss: 0.6850 - val_accuracy: 0.4231 - val_loss: 0.6906
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4706 - loss: 0.7021 - val_accuracy: 0.3846 - val_loss: 0.7097
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5686 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6961
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5392 - loss: 0.6951 - val_accuracy: 0.5385 - val_loss: 0.7032
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5000 - loss: 0.6942 - val_accuracy: 0.3462 - val_loss: 0.7092
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4608 - loss: 0.7050 - val_accuracy: 0.5000 - val_loss: 0.6894
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5294 - loss: 0.6886 - val_accuracy: 0.4231 - val_loss: 0.6923
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5784 - loss: 0.6954 - val_accuracy: 0.4231 - val_loss: 0.7206
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5490 - loss: 0.6896 - val_accuracy: 0.4231 - val_loss: 0.6883
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5196 - loss: 0.6911 - val_accuracy: 0.4615 - val_loss: 0.7175
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5000 - loss: 0.6961 - val_accuracy: 0.3077 - val_loss: 0.7185
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5784 - loss: 0.6943 - val_accuracy: 0.5000 - val_loss: 0.6880
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 1.4445e-05 - val_accuracy: 1.0000 - val_loss: 1.1589e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 1.0000 - loss: 2.0879e-05 - val_accuracy: 1.0000 - val_loss: 9.7343e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 1.0000 - loss: 1.7816e-05 - val_accuracy: 1.0000 - val_loss: 2.9728e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 1.8868e-05 - val_accuracy: 1.0000 - val_loss: 1.0420e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 2.4498e-05 - val_accuracy: 1.0000 - val_loss: 1.0080e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 1.7362e-05 - val_accuracy: 1.0000 - val_loss: 3.3386e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 1.0000 - loss: 1.8789e-05 - val_accuracy: 1.0000 - val_loss: 1.9140e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 1.0000 - loss: 2.4855e-05 - val_accuracy: 1.0000 - val_loss: 1.8486e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 2.1426e-05 - val_accuracy: 1.0000 - val_loss: 1.5821e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 1.0000 - loss: 1.7893e-05 - val_accuracy: 1.0000 - val_loss: 3.2056e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 1.0000 - loss: 1.8653e-05 - val_accuracy: 1.0000 - val_loss: 7.0241e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 1.0000 - loss: 2.7896e-05 - val_accuracy: 1.0000 - val_loss: 7.1297e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 1.0000 - loss: 2.0631e-05 - val_accuracy: 1.0000 - val_loss: 1.3197e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.7781e-05 - val_accuracy: 1.0000 - val_loss: 2.3574e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.6276e-05 - val_accuracy: 1.0000 - val_loss: 1.1749e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 1.0000 - loss: 2.3272e-05 - val_accuracy: 1.0000 - val_loss: 1.9885e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 1.5309e-05 - val_accuracy: 1.0000 - val_loss: 1.3897e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 1.0000 - loss: 1.8651e-05 - val_accuracy: 1.0000 - val_loss: 9.0497e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 2.1120e-05 - val_accuracy: 1.0000 - val_loss: 2.0308e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 1.0000 - loss: 3.0476e-05 - val_accuracy: 1.0000 - val_loss: 1.1939e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 2.1954e-05 - val_accuracy: 1.0000 - val_loss: 2.0371e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 1.8049e-05 - val_accuracy: 1.0000 - val_loss: 2.8113e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 1.0000 - loss: 1.9216e-05 - val_accuracy: 1.0000 - val_loss: 1.2708e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 1.0000 - loss: 2.2160e-05 - val_accuracy: 1.0000 - val_loss: 2.6057e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 1.0000 - loss: 2.9619e-05 - val_accuracy: 1.0000 - val_loss: 2.3045e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 2.4886e-05 - val_accuracy: 1.0000 - val_loss: 1.4534e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 1.0000 - loss: 1.8954e-05 - val_accuracy: 1.0000 - val_loss: 1.8494e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.7273e-05 - val_accuracy: 1.0000 - val_loss: 1.8862e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 2.0582e-05 - val_accuracy: 1.0000 - val_loss: 5.1641e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 2.4407e-05 - val_accuracy: 1.0000 - val_loss: 1.0257e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 1.8108e-05 - val_accuracy: 1.0000 - val_loss: 3.5064e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 1.6353e-05 - val_accuracy: 1.0000 - val_loss: 1.6095e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 1.6476e-05 - val_accuracy: 1.0000 - val_loss: 2.5223e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 1.0000 - loss: 2.5724e-05 - val_accuracy: 1.0000 - val_loss: 2.6500e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 1.0000 - loss: 2.0071e-05 - val_accuracy: 1.0000 - val_loss: 2.5376e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 1.0000 - loss: 2.3250e-05 - val_accuracy: 1.0000 - val_loss: 2.5726e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 1.0000 - loss: 1.2378e-05 - val_accuracy: 1.0000 - val_loss: 2.2300e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 2.3019e-05 - val_accuracy: 1.0000 - val_loss: 3.5568e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 1.7763e-05 - val_accuracy: 1.0000 - val_loss: 1.7485e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 1.0000 - loss: 2.9063e-05 - val_accuracy: 1.0000 - val_loss: 2.5865e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 1.9298e-05 - val_accuracy: 1.0000 - val_loss: 2.3820e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 1.0000 - loss: 3.0744e-05 - val_accuracy: 1.0000 - val_loss: 8.6939e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 1.0000 - loss: 1.4998e-05 - val_accuracy: 1.0000 - val_loss: 2.1442e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 1.0000 - loss: 2.6999e-05 - val_accuracy: 1.0000 - val_loss: 3.7657e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 1.0000 - loss: 1.7427e-05 - val_accuracy: 1.0000 - val_loss: 2.2109e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 1.0000 - loss: 2.5734e-05 - val_accuracy: 1.0000 - val_loss: 1.3527e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 1.0000 - loss: 2.3363e-05 - val_accuracy: 1.0000 - val_loss: 2.3809e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 1.0000 - loss: 1.7417e-05 - val_accuracy: 1.0000 - val_loss: 2.7514e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 1.0000 - loss: 1.9528e-05 - val_accuracy: 1.0000 - val_loss: 2.6769e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.9269e-05 - val_accuracy: 1.0000 - val_loss: 4.6714e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 2.5514e-05 - val_accuracy: 1.0000 - val_loss: 2.3241e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 1.0000 - loss: 2.0797e-05 - val_accuracy: 1.0000 - val_loss: 3.4531e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 1.0000 - loss: 2.5650e-05 - val_accuracy: 1.0000 - val_loss: 2.3644e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 1.0000 - loss: 1.5352e-05 - val_accuracy: 1.0000 - val_loss: 2.1744e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 1.2482e-05 - val_accuracy: 1.0000 - val_loss: 2.1052e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 1.3281e-05 - val_accuracy: 1.0000 - val_loss: 1.9378e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 1.0000 - loss: 2.5515e-05 - val_accuracy: 1.0000 - val_loss: 1.5633e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.3845e-05 - val_accuracy: 1.0000 - val_loss: 8.2923e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 2.2481e-05 - val_accuracy: 1.0000 - val_loss: 1.7906e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 1.0000 - loss: 2.1430e-05 - val_accuracy: 1.0000 - val_loss: 1.4507e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 2.5571e-05 - val_accuracy: 1.0000 - val_loss: 2.0565e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 1.5027e-05 - val_accuracy: 1.0000 - val_loss: 1.4313e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 1.0000 - loss: 3.7357e-05 - val_accuracy: 1.0000 - val_loss: 1.6192e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 1.0000 - loss: 9.1606e-06 - val_accuracy: 1.0000 - val_loss: 1.4828e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 1.0000 - loss: 2.3683e-05 - val_accuracy: 1.0000 - val_loss: 1.9898e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 1.0465e-05 - val_accuracy: 1.0000 - val_loss: 2.6406e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 2.9490e-05 - val_accuracy: 1.0000 - val_loss: 1.5514e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 1.0000 - loss: 1.7379e-05 - val_accuracy: 1.0000 - val_loss: 2.3466e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 1.0000 - loss: 2.6707e-05 - val_accuracy: 1.0000 - val_loss: 2.1583e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 2.1787e-05 - val_accuracy: 1.0000 - val_loss: 3.3536e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 2.8641e-05 - val_accuracy: 1.0000 - val_loss: 2.7408e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 1.0000 - loss: 1.8885e-05 - val_accuracy: 1.0000 - val_loss: 1.7677e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 1.6288e-05 - val_accuracy: 1.0000 - val_loss: 1.2429e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 2.2305e-05 - val_accuracy: 1.0000 - val_loss: 2.8793e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 2.0341e-05 - val_accuracy: 1.0000 - val_loss: 8.2954e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 1.0000 - loss: 1.9601e-05 - val_accuracy: 1.0000 - val_loss: 1.1337e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 1.0000 - loss: 2.4125e-05 - val_accuracy: 1.0000 - val_loss: 1.3741e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 2.0035e-05 - val_accuracy: 1.0000 - val_loss: 1.5680e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 1.6269e-05 - val_accuracy: 1.0000 - val_loss: 1.5855e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 1.0000 - loss: 1.6303e-05 - val_accuracy: 1.0000 - val_loss: 2.0052e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 1.0000 - loss: 9.0157e-06 - val_accuracy: 1.0000 - val_loss: 4.3677e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 1.0000 - loss: 2.7908e-05 - val_accuracy: 1.0000 - val_loss: 3.2131e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 1.0000 - loss: 2.2346e-05 - val_accuracy: 1.0000 - val_loss: 2.8751e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 1.4766e-05 - val_accuracy: 1.0000 - val_loss: 2.6061e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 1.0000 - loss: 2.3201e-05 - val_accuracy: 1.0000 - val_loss: 1.4573e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 1.0000 - loss: 1.5088e-05 - val_accuracy: 1.0000 - val_loss: 2.7267e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 1.8437e-05 - val_accuracy: 1.0000 - val_loss: 9.3932e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 1.9998e-05 - val_accuracy: 1.0000 - val_loss: 9.4807e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 1.0000 - loss: 1.8353e-05 - val_accuracy: 1.0000 - val_loss: 1.7406e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 1.0000 - loss: 1.5756e-05 - val_accuracy: 1.0000 - val_loss: 9.5741e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 1.0000 - loss: 2.5500e-05 - val_accuracy: 1.0000 - val_loss: 1.8243e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 1.0000 - loss: 1.9528e-05 - val_accuracy: 1.0000 - val_loss: 3.1263e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 1.0000 - loss: 2.5798e-05 - val_accuracy: 1.0000 - val_loss: 2.4604e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 1.0000 - loss: 1.9152e-05 - val_accuracy: 1.0000 - val_loss: 4.6212e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 1.0000 - loss: 1.9795e-05 - val_accuracy: 1.0000 - val_loss: 2.2524e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 1.3900e-05 - val_accuracy: 1.0000 - val_loss: 1.3021e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 1.6129e-05 - val_accuracy: 1.0000 - val_loss: 8.8812e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 1.0000 - loss: 1.5557e-05 - val_accuracy: 1.0000 - val_loss: 1.1017e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 1.6369e-05 - val_accuracy: 1.0000 - val_loss: 1.9896e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
import matplotlib.pyplot as plt

# Plotting epoch losses and accuracies
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history['epoch_loss'], label='Loss')
plt.title('Epoch Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history['epoch_accuracy'], label='Accuracy')
plt.title('Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# You can add more plots for batch-level data, rewards, thresholds, etc.

# %%
# # for later check
# agent = Agent(pn_model, alpha=0.00001, gamma=0.99)
# # Example parameters
# n_epochs = 300
# n_epochs = 10
# batch_size = 128 # You can adjust the batch size as needed

# def shuffle_data(x_train, y_train, s):
#     indices = np.arange(len(x_train))
#     np.random.shuffle(indices)
#     return x_train[indices], y_train[indices], s[indices]

# def create_mini_batches(x_train, y_train, s, batch_size):
#     for start_idx in range(0, len(x_train) - batch_size + 1, batch_size):
#         excerpt = slice(start_idx, start_idx + batch_size)
#         yield x_train[excerpt], y_train[excerpt], s[excerpt]

# def calculate_threshold(clf_probabilities, y_batch):
#     # Identify indices of positive examples
#     positive_indices = (y_batch == 1)
    
#     # Calculate threshmin from positive examples
#     if np.any(positive_indices):
#         threshmin = np.min(clf_probabilities[positive_indices])
#     else:
#         threshmin = 0  # Default value if no positive examples are present

#     # Identify U0 - samples with predictions >= threshmin
#     U0_indices = (clf_probabilities >= threshmin)
    
#     # Calculate the final threshold using Equation 5
#     if np.any(U0_indices):
#         threshold = np.mean(clf_probabilities[U0_indices])
#     else:
#         threshold = threshmin  # Use threshmin if no samples meet the U0 criteria

#     return threshold


# for epoch in range(1, n_epochs + 1):
#     x_train_shuffled, y_train_shuffled, s_shuffled = shuffle_data(x_train, y_train, s)
    
#     for x_batch, y_batch, s_batch in create_mini_batches(x_train_shuffled, y_train_shuffled, s_shuffled, batch_size):
#         # 
#         probabilities = pn_model.predict(x_batch)
#         # print(f"Probabilities = {probabilities}")
#         threshold = min(probabilities[y_batch == 1])
#         print(f"Threshold = {threshold}")
#         predicted_labels = (probabilities >= threshold).astype(int)
#         pn_predicted_labels = predicted_labels.flatten().astype(int)

#         # actions = policy_network.predict_action(x_batch)

#         actions = []
#         probabilities = []
#         for x in x_batch:
#             action, probability  = agent.choose_action(x)
#             actions.append(action)
#             probabilities.append(probability)

#         actions = np.array(actions)

#         # Check shapes before training to debug
#         # if pn_predicted_labels.ndim > 1:
#         #     pn_predicted_labels = np.squeeze(pn_predicted_labels)
#         print(f"x_batch shape: {x_batch.shape}")
#         print(f"actions shape: {pn_predicted_labels.shape}")
#         print(f"Action: {pn_predicted_labels}" )
#         # Ensuring that pn_predicted_labels is a flat numpy array, not a numpy array of objects or something else
#         # if isinstance(pn_predicted_labels, list):
#         #     pn_predicted_labels = np.array(pn_predicted_labels)
#         # elif isinstance(pn_predicted_labels, np.ndarray) and pn_predicted_labels.dtype == object:
#         #     pn_predicted_labels = np.concatenate(pn_predicted_labels)

#         # Redundant reshaping to ensure compatibility
#         # pn_predicted_labels = pn_predicted_labels.reshape(-1)
#         # print(f"actions shape 2: {pn_predicted_labels.shape}")



#         # now train classifier on policy network predicted label
#         # history_1 = model_1.fit(x_batch, pn_predicted_labels, epochs=1, batch_size=len(x_batch), validation_split=0.2)
#         history_1 = model_1.fit(x_batch, actions, epochs=1, batch_size=len(x_batch), validation_split=0.2)
#         clf_probabilities = model_1.predict(x_batch)
#         # threshold = min(clf_probabilities[y_batch == 1])
#         threshold = calculate_threshold(clf_probabilities, y_batch)
#         # clf_predicted_labels = (clf_probabilities >= threshold).astype(int)
#         # clf_predicted_labels = clf_predicted_labels.flatten().astype(int)
#         # Calculate rewards based on the threshold
#         rewards = []
#         for prob, actual in zip(clf_probabilities, y_batch):
#             if actual == 1 or (actual == 0 and prob >= threshold):
#                 reward = prob
#             else:
#                 reward = 1 - prob
#             rewards.append(reward)

#         # Store transitions and learn from them
#         # for state, action, reward in zip(x_batch, actions, rewards):
#         for state, action, reward in zip(x_batch, pn_predicted_labels, rewards):
#             agent.store_transition(state, action, reward)
#         agent.learn()
#         print("Agent learned")
        

        
#         pass
    
#     if epoch % 3 == 0:  # Every 3 epochs
#         print("Call learn policy here!")

# %%
import gym
# if __name__ == '__main__':
agent = Agent(alpha=0.0005, gamma=0.99, model=pn_model)

# env = gym.make('LunarLander-v2')
score_history = []

num_episodes = 10 #2000

for i in range(num_episodes):
    done = False
    score = 0
    observation = env.reset()
    print(f"Obeservation: {observation}")
    while not done:
        action = agent.choose_action(observation)
        # observation_, reward, done, info = env.step(action)
        observation_, predictid_label, done, info = env.step(action)
        agent.store(observation, action, reward)
        observation = observation_
        score += reward
    score_history.append(score)

    agent.learn()
    avg_score = np.mean(score_history[-100:])
    print('episode: ', i,'score: %.1f' % score,
        'average score %.1f' % avg_score)

# %%
# loop here
for epoch in range(10):
    
    probabilities = pn_model.predict(x_train)
    threshold = min(probabilities[y_train == 1])

    # Convert probabilities to binary labels based on the threshold
    threshold =0.5
    predicted_labels = (probabilities >= threshold).astype(int)
    policy_predicted_labels = predicted_labels.flatten().astype(int)

    print(f"Policy predicted labels distribution: {epoch}", np.bincount(policy_predicted_labels))

    history_1 = model_1.fit(x_train, policy_predicted_labels, epochs=5, batch_size=32, validation_split=0.2)
    probabilities = pn_model.predict(x_train)
    threshold = min(probabilities[y_train == 1])
    predicted_labels = (probabilities >= threshold).astype(int)
    clf_predicted_labels = predicted_labels.flatten().astype(int)
    print(f"Classifer predicted labels distribution: {epoch}", np.bincount(clf_predicted_labels))

# %% [markdown]
# # Visual

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_images(images, labels, predictions=None):
    """Plot images with their labels. Show predictions if provided."""
    n = images.shape[0]
    sqrt_val = int(np.ceil(np.sqrt(n)))
    fig, axes = plt.subplots(sqrt_val, sqrt_val, figsize=(10, 10))
    
    for i, ax in enumerate(axes.flat):
        if i >= n:
            break
        ax.imshow(images[i], cmap='binary')
        
        if predictions is not None:
            ax.set_title(f"True: {labels[i]}\nPred: {predictions[i]}")
        else:
            ax.set_title(f"Label: {labels[i]}")
        
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()

# Predictions from the second classifier
predictions = model_2.predict(X_test_reshaped)
predicted_classes = (predictions > 0.5).astype(int).flatten()  # Assuming binary classification

# Selecting a few images to display
indices = np.random.choice(range(len(x_test)), 25, replace=False)  # Randomly select 25 images
selected_images = x_test[indices]
selected_labels = y_test[indices]
selected_predictions = predicted_classes[indices]

# Plotting
plot_images(selected_images, selected_labels, selected_predictions)

# %%
def plot_history(history):
    """Plot training and validation loss and accuracy."""
    fig, axs = plt.subplots(2, 1, figsize=(10, 10))
    axs[0].plot(history.history['loss'], label='train')
    axs[0].plot(history.history['val_loss'], label='validation')
    axs[0].set_title('Loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()

    axs[1].plot(history.history['accuracy'], label='train')
    axs[1].plot(history.history['val_accuracy'], label='validation')
    axs[1].set_title('Accuracy')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()

    plt.show()

# Assuming you have stored the history of training your models as `history_1` and `history_2`
plot_history(history_1)  # For the first classifier
plot_history(history_2)  # For the second classifier
